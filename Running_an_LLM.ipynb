# %% [markdown]
# <a href="https://colab.research.google.com/github/realharinarayan/hari_project_demo/blob/main/Running_an_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install the Dependencies

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 54.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import the model

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model='distilbert-base-uncased')

# %% [markdown]
# # Enter the input and check the output

# %%
unmasker("This is a very [MASK] project")
# Out:
# [{'score': 0.09013699740171432,
#   'token': 12479,
#   'token_str': 'ambitious',
#   'sequence': 'this is a very ambitious project'},
#  {'score': 0.04837000370025635,
#   'token': 5875,
#   'token_str': 'interesting',
#   'sequence': 'this is a very interesting project'},
#  {'score': 0.03539068251848221,
#   'token': 2590,
#   'token_str': 'important',
#   'sequence': 'this is a very important project'},
#  {'score': 0.029017698019742966,
#   'token': 3144,
#   'token_str': 'successful',
#   'sequence': 'this is a very successful project'},
#  {'score': 0.02346334047615528,
#   'token': 5866,
#   'token_str': 'unusual',
#   'sequence': 'this is a very unusual project'}]

# %%
# !pip install transformers
from transformers import pipeline
unmasker = pipeline('fill-mask', model='distilbert-base-uncased')
unmasker("This is a very [MASK] project")
